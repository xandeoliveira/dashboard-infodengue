# %% [markdown]
# # Obtendo dados do Infodengue
#
# Para buscar dados na API do Infodengue deve-se usar a seguinte url: `https://info.dengue.mat.br/api/alertcity?params` sendo que `params` é composto pelas variáveis: geocode, `disease`, `format`, `ew_start`, `ew_end`, `ey_start`, `ey_end`.
#
# Mais detalhes no [tutorial oficial](https://info.dengue.mat.br/services/tutorial/Python) ou na [página oficial](https://info.dengue.mat.br/).

# %%
import pandas as pd

# %%
def url_factory(geocode, ew_start, ew_end, ey_start, ey_end):
    params = (
        "https://info.dengue.mat.br/api/alertcity?",
        "&disease=", "dengue",
        "&geocode=", geocode,
        "&disease=", "dengue",
        "&format=", "csv",
        "&ew_start=", ew_start,
        "&ew_end=", ew_end,
        "&ey_start=" , ey_start,
        "&ey_end=", ey_end    
    )
    
    return "".join(map(str, params))

# %%
url_acarape_2024 = url_factory(2300150, 1, 54, 2024, 2024)

# %%
df = pd.read_csv(url_acarape_2024, index_col='SE')
df.head(10)
# Out:
#         data_iniSE  casos_est  casos_est_min  casos_est_max  casos     p_rt1  \
# SE
# 202452  2024-12-22        0.0              0              0      0  0.000000
# 202451  2024-12-15        0.0              0              0      0  0.000000
# 202450  2024-12-08        0.0              0              0      0  0.000000
# 202449  2024-12-01        0.0              0              0      0  0.000000
# 202448  2024-11-24        0.0              0              0      0  0.000000
# 202447  2024-11-17        1.0              1              1      1  0.728247
# 202446  2024-11-10        0.0              0              0      0  0.000000
# 202445  2024-11-03        1.0              1              1      1  0.782203
# 202444  2024-10-27        0.0              0              0      0  0.000000
# 202443  2024-10-20        0.0              0              0      0  0.000000
#
#         p_inc100k  Localidade_id  nivel                  id  ...    umidmed  \
# ...

# %%
df = df[["data_iniSE","casos"]]

df.head(3)
# Out:
#         data_iniSE  casos
# SE
# 202452  2024-12-22      0
# 202451  2024-12-15      0
# 202450  2024-12-08      0

# %% [markdown]
# ## Divisão de data_iniSE em ano e mês

# %%
df['data_iniSE'] = pd.to_datetime(df['data_iniSE'])
df.head(3)
# Out:
#        data_iniSE  casos
# SE
# 202452 2024-12-22      0
# 202451 2024-12-15      0
# 202450 2024-12-08      0

# %%
df['year'] = df['data_iniSE'].dt.year
df['month'] = df['data_iniSE'].dt.month

df.head(3)
# Out:
#        data_iniSE  casos  year  month
# SE
# 202452 2024-12-22      0  2024     12
# 202451 2024-12-15      0  2024     12
# 202450 2024-12-08      0  2024     12
